# %% [markdown]
# # Raw 데이터 수집
#
# 국가법령정보 API에서 부동산/임대차 관련 문서를 수집하여 `data/raw/{target}.jsonl`에 저장한다.
#
# | target  | 설명                  | 중복 제거 기준       |
# | ------- | --------------------- | -------------------- |
# | `acr`   | 국민권익위원회 결정문 | `결정문일련번호`     |
# | `eflaw` | 현행법령              | `법령ID`             |
# | `prec`  | 판례                  | `판례일련번호`       |
# | `expc`  | 법령해석례            | `법령해석례일련번호` |
#
# > 각 섹션은 독립적으로 실행 가능. 전체 실행 시 **Kernel → Restart & Run All**.

# %% [markdown]
# ## 0. 공통 설정

# %%
import sys

sys.path.insert(0, "..")
from src.api import fetch_list, save_raw, fetch_details

# %% [markdown]
# ## 2. 법령해석례(expc)

# %%
EXPC_QUERIES: list[str] = [
    "임대차",
    "보증금",
    "주택임대차",
    "전세",
    "임차인",
]

# %%
seen_expc: set[str] = set()  # 수집된 법정해석례 일련번호 추적
expc_items: list[dict] = []

for query in EXPC_QUERIES:
    items = fetch_list("expc", query=query, max_items=None, extra_params={"search": 2})
    for item in items:
        doc_id = str(item.get("법령해석례일련번호", ""))
        # doc_id가 비어있거나 이미 수집한 항목이면 skip
        if doc_id and doc_id not in seen_expc:
            seen_expc.add(doc_id)
            expc_items.append(item)

save_raw(expc_items, target="expc", mode="w")

print(len(expc_items))
# Out:
# 365

# %%
expc_details = fetch_details(
  target="expc",
  items=expc_items,
  id_field="법령해석례일련번호",
)

# 목록만 있는 expc.jsonl 덮어쓰기
result = save_raw(expc_details, target="expc", mode="w")
print(len(expc_details))
# Out:
# 365

# %% [markdown]
# ## 3. 판례 (prec)

# %%
# 임대차 분쟁에서 자주 다뤄지는 판례 관련 키워드
PREC_QUERIES: list[str] = [
    "임대차",
    "보증금",
    "전세",
    "임차인",
    "계약갱신청구권",
    "원상회복",
    "수선의무",
    "명도",
]

# %%
seen_prec: set[str] = set() # 수집된 판례일련번호
prec_items: list[dict] = [] 

for query in PREC_QUERIES:
    items = fetch_list("prec", query=query, max_items=None, extra_params={"search": 2})
    for item in items:
        doc_id = str(item.get("판례일련번호", ""))
        # doc_id가 비어있거나 이미 수집한 항목이면 skip
        if doc_id and doc_id not in seen_prec:
            seen_prec.add(doc_id)
            prec_items.append(item)

save_raw(prec_items, target="prec", mode="w")

print(len(prec_items))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 seen_prec: set[str] = set() # 수집된 판례일련번호
#       2 prec_items: list[dict] = []
#       3
#       4 for query in PREC_QUERIES:
# ----> 5     items = fetch_list("prec", query=query, max_items=None, extra_params={"search": 2})
#       6     for item in items:
#       7         doc_id = str(item.get("판례일련번호", ""))
#       8         # doc_id가 비어있거나 이미 수집한 항목이면 skip
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/notebooks/../src/api/collector.py:39, in fetch_list(target, query, max_items, extra_params)
#      37 items: list[dict[str, Any]] = _extract_list_items(first, target)
#      38 for page in range(2, total_pages + 1):
# ---> 39   resp = api(target=target, service="search", params={**base, "page": page})
#      40   items.extend(_extract_list_items(resp, target))
#      42 return items[:max_items] if max_items else items
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/notebooks/../src/api/api.py:56, in api(oc, target, service, response_type, params, timeout)
#      48 url = _SERVICE_URL if service == "detail" else _SEARCH_URL
#      49 require_params = {
#      50   "OC": oc,
#      51   "type": response_type,
#      52   "target": target,
#      53   **(params or {})
#      54 }
# ---> 56 response = _session.get(url, params=require_params, timeout=timeout)
#      57 response.raise_for_status()
#      59 if response_type == "JSON":
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/requests/sessions.py:605, in Session.get(self, url, **kwargs)
#     597 r"""Sends a GET request. Returns :class:`Response` object.
#     598
#     599 :param url: URL for the new :class:`Request` object.
#     600 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     601 :rtype: requests.Response
#     602 """
#     604 kwargs.setdefault("allow_redirects", True)
# --> 605 return self.request("GET", url, **kwargs)
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/requests/sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587 send_kwargs = {
#     588     "timeout": timeout,
#     589     "allow_redirects": allow_redirects,
#     590 }
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/requests/sessions.py:749, in Session.send(self, request, **kwargs)
#     746         pass
#     748 if not stream:
# --> 749     r.content
#     751 return r
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/requests/models.py:904, in Response.content(self)
#     902         self._content = None
#     903     else:
# --> 904         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     906 self._content_consumed = True
#     907 # don't need to release the connection; that's been handled by urllib3
#     908 # since we exhausted the data.
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820 if hasattr(self.raw, "stream"):
#     821     try:
# --> 822         yield from self.raw.stream(chunk_size, decode_content=True)
#     823     except ProtocolError as e:
#     824         raise ChunkedEncodingError(e)
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/urllib3/response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1234 """
#    1235 A generator wrapper for the read() method. A call will block until
#    1236 ``amt`` bytes have been read from the connection or until the
#    (...)   1247     'content-encoding' header.
#    1248 """
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/urllib3/response.py:1421, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1419     if self.chunk_left == 0:
#    1420         break
# -> 1421     chunk = self._handle_chunk(amt)
#    1422 decoded = self._decode(
#    1423     chunk,
#    1424     decode_content=decode_content,
#    1425     flush_decoder=False,
#    1426     max_length=amt,
#    1427 )
#    1428 if decoded:
#
# File ~/Documents/study/sknetworks/00_hw/09_chatbot/.venv/lib/python3.12/site-packages/urllib3/response.py:1363, in HTTPResponse._handle_chunk(self, amt)
#    1361     returned_chunk = value
#    1362 else:  # amt > self.chunk_left
# -> 1363     returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
#    1364     self._fp._safe_read(2)  # type: ignore[union-attr] # Toss the CRLF at the end of the chunk.
#    1365     self.chunk_left = None
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/http/client.py:642, in HTTPResponse._safe_read(self, amt)
#     635 def _safe_read(self, amt):
#     636     """Read the number of bytes requested.
#     637
#     638     This function should be used when <amt> bytes "should" be present for
#     639     reading. If the bytes are truly not available (due to EOF), then the
#     640     IncompleteRead exception can be used to detect the problem.
#     641     """
# --> 642     data = self.fp.read(amt)
#     643     if len(data) < amt:
#     644         raise IncompleteRead(data, amt-len(data))
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
prec_details = fetch_details(
  target="prec",
  items=prec_items,
  id_field="판례일련번호",
)

# 목록만 있는 prec.jsonl 덮어쓰기
result = save_raw(prec_details, target="prec", mode="w")
print(len(prec_details))

# %% [markdown]
# ## 4.

# %%
# 임대차 관련 법령 해석 키워드


EFLAW_QUERIES: list[str] = [
    "주택임대차보호법",
    "상가건물임대차보호법",
    "민법",
    "부동산",
    "전세사기",
]

# %%
seen_expc: set[str] = set()
expc_items: list[dict] = []

for query in EXPC_QUERIES:
    items = fetch_list("expc", query=query, max_items=None)
    for item in items:
        # 법령해석례일련번호: 본문 조회 시 ID 파라미터로 사용
        doc_id = str(item.get("법령해석례일련번호", ""))
        if doc_id and doc_id not in seen_expc:
            seen_expc.add(doc_id)
            expc_items.append(item)

print(f"수집: {len(expc_items)}건 (중복 제거 후)")
expc_items[:3]

# %%
path = save_raw(expc_items, target="expc", mode="w")
print(f"저장 완료: {path}")

# %% [markdown]
# ---
#
# ## 5. 수집 결과 요약

# %%
from pathlib import Path

raw_dir = Path("../data/raw")

# 각 target의 .jsonl 파일 존재 여부 및 수집 건수 확인
# JSONL은 한 줄 = 한 건이므로 줄 수 = 수집 건수
for target in ["acr", "eflaw", "prec", "expc"]:
    path = raw_dir / f"{target}.jsonl"
    if path.exists():
        count = sum(1 for _ in path.open(encoding="utf-8"))
        print(f"{target:8s}: {count:5d}건  →  {path}")
    else:
        print(f"{target:8s}: 파일 없음")
